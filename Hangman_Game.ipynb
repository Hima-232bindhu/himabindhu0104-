# %% [markdown]
# <a href="https://colab.research.google.com/github/Hima-232bindhu/himabindhu0104-/blob/main/Hangman_Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random


words = ["python", "hangman", "computer", "programming", "challenge"]


def choose_word():
    return random.choice(words)


def display_word(word, guessed_letters):
    display = ""
    for letter in word:
        if letter in guessed_letters:
            display += letter
        else:
            display += "_"
    return display


def play_hangman():
    word_to_guess = choose_word()
    guessed_letters = []
    attempts = 6

    print("Welcome to Hangman!")

    while attempts > 0:
        print("\nWord: " + display_word(word_to_guess, guessed_letters))
        print("Attempts left:", attempts)

        guess = input("Guess a letter: ").lower()

        if len(guess) == 1 and guess.isalpha():
            if guess in guessed_letters:
                print("You've already guessed that letter.")
            elif guess in word_to_guess:
                print("Good guess!")
                guessed_letters.append(guess)
                if set(word_to_guess).issubset(set(guessed_letters)):
                    print("Congratulations! You've guessed the word:", word_to_guess)
                    break
            else:
                print("Wrong guess!")
                guessed_letters.append(guess)
                attempts -= 1
        else:
            print("Invalid input. Please enter a single letter.")

    if attempts == 0:
        print("You ran out of attempts. The word was:", word_to_guess)


play_hangman()
# Out:
# Welcome to Hangman!
#
# Word: ________
# Attempts left: 6
# Guess a letter: c
# Good guess!
#
# Word: c_______
# Attempts left: 6
# Guess a letter: o
# Good guess!
#
# Word: co______
# Attempts left: 6
# Guess a letter: m
# Good guess!
#
# Word: com_____
# Attempts left: 6
# Guess a letter: o
# You've already guessed that letter.
#
# Word: com_____
# Attempts left: 6
# Guess a letter: l
# Wrong guess!
#
# Word: com_____
# Attempts left: 5
# Guess a letter: p
# Good guess!
#
# Word: comp____
# Attempts left: 5
# Guess a letter: h
# Wrong guess!
#
# Word: comp____
# Attempts left: 4
# Guess a letter: u
# Good guess!
#
# Word: compu___
# Attempts left: 4
# Guess a letter: t
# Good guess!
#
# Word: comput__
# Attempts left: 4
# Guess a letter: j
# Wrong guess!
#
# Word: comput__
# Attempts left: 3
# Guess a letter: j
# You've already guessed that letter.
#
# Word: comput__
# Attempts left: 3
# Guess a letter: r
# Good guess!
#
# Word: comput_r
# Attempts left: 3
# Guess a letter: t
# ...
